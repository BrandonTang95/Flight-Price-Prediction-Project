# %%
pip install opendatasets
# Out:
# ...
#    ---------------------------------------- 0.0/181.2 kB ? eta -:--:--
#    -------------------------------------- - 174.1/181.2 kB 5.3 MB/s eta 0:00:01
#    ---------------------------------------- 181.2/181.2 kB 3.6 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import opendatasets as od

# This will download the data into a folder named "flight-price-prediction"
od.download("https://www.kaggle.com/datasets/shubhambathwal/flight-price-prediction")
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username:
#   BrandonTang95
# Your Kaggle Key:
#   ········
# Dataset URL: https://www.kaggle.com/datasets/shubhambathwal/flight-price-prediction
# ...
# 100%|██████████████████████████████████████████████████████████████████████████████| 4.16M/4.16M [00:00<00:00, 586MB/s]
